# %%
import dataset_tools as dtools

dtools.download(dataset='KITTI MOTS', dst_dir='~/dataset-ninja/')
# Out:
# ...
# Unpacking 'kitti-mots.tar': 100%|██████████| 57325/57325 [03:44<00:00, 255.76file/s]
# '//DATA/home/jgarcia/dataset-ninja/kitti-mots'
